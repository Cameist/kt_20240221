# %% [markdown]
# # 안녕하세요, 에이블러 여러분!
# ## AIVLE스쿨 1차 미니프로젝트 '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "버스 정류장 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn

# %% [markdown]
# ## 기본전제
# * 제공되는 기본/추가 데이터는 '에이블러용' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.1 bus_station_boarding_month_202401.csv
#
# * 서울시 버스노선별 정류장별 승하차 인원 정보
# * https://data.seoul.go.kr/dataList/OA-12912/S/1/datasetView.do
#
#
# [추가 데이터]
# * 1.1 bus_station_202401.xlsx
#
# * 서울시 버스정류장 위치정보
# * https://data.seoul.go.kr/dataList/OA-15067/S/1/datasetView.do

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터입니다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 sklearn 라이브러리를 통해 모델을 학습시키고 저장할 때 많이 사용, 파이썬의 모든 객체를 파일로 저장할 수 있다.

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 '1.1 bus_station_boarding_month_202401.csv'파일을 'bus_station' 변수에 저장하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * cp949 인코더를 사용해 주세요

# %%
# 아래 실습코드를 실행해주세요.

import sys
import numpy as np
import pandas as pd

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

bus_station = pd.read_csv('1.1 bus_station_boarding_month_202401.csv', sep=",", encoding = "cp949")

# %%
# 데이터 프레임의 Shape을 확인합니다.

bus_station.shape
# Out:
# (1048575, 8)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'bus_station' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보세요.

# %%
bus_station.head()
# Out:
#        사용일자  노선번호                  노선명 버스정류장ARS번호                        역명  \
# 0  20240101   101        101번(화계사~동대문)       6178            대광고등학교앞(00055)
# 1  20240101  9408  9408번(구미동차고지~고속터미널)      22337      헌인마을.서울농업기술센터(00042)
# 2  20240101  9408  9408번(구미동차고지~고속터미널)      22336      헌인마을.서울농업기술센터(00078)
# 3  20240101  9408  9408번(구미동차고지~고속터미널)      22334  헌인릉.강남서초과학화예비군훈련장(00043)
# 4  20240101  9408  9408번(구미동차고지~고속터미널)      22333  헌인릉.강남서초과학화예비군훈련장(00076)
#
#    승차총승객수  하차총승객수      등록일자
# 0      39      76  20240104
# 1       1       0  20240104
# 2       2       0  20240104
# 3       0       2  20240104
# 4       2       1  20240104

# %%
bus_station.tail()
# Out:
#              사용일자  노선번호               노선명 버스정류장ARS번호                역명  \
# 1048570  20240126  종로05  종로05(서대문역~배화여중고)       1837     스위스대사관(00025)
# 1048571  20240126  종로05  종로05(서대문역~배화여중고)       1831       월암공원(00024)
# 1048572  20240126  종로05  종로05(서대문역~배화여중고)       1514   적십자병원후문앞(00002)
# 1048573  20240126  성북07  성북07(정릉4동종점~길음역)       8454     정릉4동종점(00014)
# 1048574  20240126  종로05  종로05(서대문역~배화여중고)       1587  신학대학교총회본부(00011)
#
#          승차총승객수  하차총승객수      등록일자
# 1048570       1      19  20240129
# 1048571      25      21  20240129
# 1048572       9       6  20240129
# 1048573       0     181  20240129
# 1048574      13      68  20240129

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
bus_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 8 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   사용일자        1048575 non-null  int64
#  1   노선번호        1048575 non-null  object
#  2   노선명         1048575 non-null  object
#  3   버스정류장ARS번호  1048575 non-null  object
#  4   역명          1048575 non-null  object
#  5   승차총승객수      1048575 non-null  int64
#  6   하차총승객수      1048575 non-null  int64
#  7   등록일자        1048575 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 64.0+ MB

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 bus_station.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Jan-01'

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
bus_station.describe()
# Out:
#                사용일자        승차총승객수        하차총승객수          등록일자
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   2.024011e+07  1.030953e+02  1.010178e+02  2.024012e+07
# std    7.455044e+00  1.486801e+02  1.348374e+02  7.455044e+00
# min    2.024010e+07  0.000000e+00  0.000000e+00  2.024010e+07
# 25%    2.024011e+07  1.300000e+01  1.600000e+01  2.024011e+07
# 50%    2.024011e+07  5.700000e+01  6.200000e+01  2.024012e+07
# 75%    2.024012e+07  1.370000e+02  1.370000e+02  2.024012e+07
# max    2.024013e+07  5.027000e+03  4.352000e+03  2.024013e+07

# %% [markdown]
# #### [실습문제3] 위 데이터에서 버스정류장 위치를 구 별로 구분 해보기
#
# * 'bus_station' 데이터의 정보를 확인해보세요.
#
# * 버스정류장 ARS번호의 앞 두자리가 구를 의미합니다.
#
# * '자치구' column을 추가 -> 정류장이 위치한 구 이름을 등록

# %%
# "버스정류장ARS번호" 컬럼 확인하기

bus_station[['버스정류장ARS번호']]
# Out:
#         버스정류장ARS번호
# 0             6178
# 1            22337
# 2            22336
# 3            22334
# 4            22333
# ...            ...
# 1048570       1837
# 1048571       1831
# 1048572       1514
# 1048573       8454
# 1048574       1587
#
# [1048575 rows x 1 columns]

# %%
# 버스정류장 ARS번호에서 시작하는 앞자리 2개로 '자치구'라는 새로운 컬럼 생성
# str() : 정수나 실수를 문자열 형태로 바꿔주는 함수, slice()
#문자열로ㅓ 하나씩 받아와서 슬라이싱해서ㅡ 리턴,,.
#str(bus_station['버스정류장ARS번호'][i][slice(2)])
list=[]
for i in bus_station['버스정류장ARS번호']:
    if len(i)<5:
        list.append(str(i[slice(0,1)]))
    else:
        list.append(str(i[slice(0,2)]))
bus_station['자치구']=list
bus_station['자치구']
# Out:
# 0           6
# 1          22
# 2          22
# 3          22
# 4          22
#            ..
# 1048570     1
# 1048571     1
# 1048572     1
# 1048573     8
# 1048574     1
# Name: 자치구, Length: 1048575, dtype: object

# %% [markdown]
# * 버스정류장 ARS 번호 : 01~25까지 앞 숫자 두개가 위치한 구를 의미
#     01. 종로구
#     02. 중구
#     03. 용산구
#     04. 성동구
#     05. 광진구
#     06. 동대문구
#     07. 중랑구
#     08. 성북구
#     09. 강북구
#     10. 도봉구
#     11. 노원구
#     12. 은평구
#     13. 서대문구
#     14. 마포구
#     15. 양천구
#     16. 강서구
#     17. 구로구
#     18. 금천구
#     19. 영등포구
#     20. 동작구
#     21. 관악구
#     22. 서초구
#     23. 강남구
#     24. 송파구
#     25. 강동구

# %%
# 구 코드를 구 이름으로 변환하기
# map() : 리스트, 튜플 등 반복 가능한 데이터 집합을 입력으로 받아 변환하는 함수

bus_station['자치구'] = bus_station['자치구'].map({
    '1': '종로구',
    '2': '중구',
    '3': '용산구',
    '4': '성동구',
    '5': '광진구',
    '6': '동대문구',
    '7': '중랑구',
    '8': '성북구',
    '9': '강북구',
    '10': '도봉구',
    '11': '노원구',
    '12': '은평구',
    '13': '서대문구',
    '14': '마포구',
    '15': '양천구',
    '16': '강서구',
    '17': '구로구',
    '18': '금천구',
    '19': '영등포구',
    '20': '동작구',
    '21': '관악구',
    '22': '서초구',
    '23': '강남구',
    '24': '송파구',
    '25': '강동구'})

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
bus_station['자치구'].tail(10)
# Out:
# 1048565    종로구
# 1048566    종로구
# 1048567    종로구
# 1048568    종로구
# 1048569    종로구
# 1048570    종로구
# 1048571    종로구
# 1048572    종로구
# 1048573    성북구
# 1048574    종로구
# Name: 자치구, dtype: object

# %% [markdown]
# #### [실습문제4] 결측치 처리하기

# %%
# (가상), (기점가상) 정류장은 ARS번호가 '~'로 나옵니다.
# (가상) 정류장 : 버스정보시스템 상에서 위치 정보를 표시하기 위해 임의로 가상의 정류장을 설정, 실제하지 않음
# '버스정류장ARS번호'가 '~'인 곳을 확인해주세요.
bus_station.loc[bus_station['버스정류장ARS번호'] == '~']
# Out:
#              사용일자  노선번호                      노선명 버스정류장ARS번호  \
# 699      20240101   441      441번(월암공영차고지~신사사거리)          ~
# 1261     20240101  7021     7021번(은평공영차고지~롯데백화점)          ~
# 1337     20240101  7017     7017번(은평공영차고지~롯데백화점)          ~
# 1427     20240101  7016         7016번(은평차고지~상명대)          ~
# 3332     20240101  750B         750B번(은평차고지~서울대)          ~
# ...           ...   ...                      ...        ...
# 1040945  20240126   271  271번(용마문화복지센터~월드컵파크7단지)          ~
# 1040953  20240126   271  271번(용마문화복지센터~월드컵파크7단지)          ~
# 1041836  20240126   N64    N64번(염곡공영차고지~강서공영차고지)          ~
# 1042754  20240126   N72  N72중랑 (중랑공영차고지~은평공영차고지)          ~
# 1043252  20240126   01A        01A번(예장주차장~예장주차장)          ~
#
#                                역명  승차총승객수  하차총승객수      등록일자  자치구
# 699            월암차고지(종점가상)(00126)       0       1  20240104  NaN
# 1261           은평공영차고지(가상)(00076)       0      10  20240104  NaN
# 1337           은평공영차고지(가상)(00090)       0      10  20240104  NaN
# 1427           은평공영차고지(가상)(00107)       0      16  20240104  NaN
# 3332           은평공영차고지(가상)(00076)       0      15  20240104  NaN
# ...                           ...     ...     ...       ...  ...
# 1040945         경성여객(종점가상)(00125)       0      35  20240129  NaN
# 1040953         경성여객(기점가상)(00001)      61      12  20240129  NaN
# 1041836         대흥교통(기점가상)(00001)       0       1  20240129  NaN
# 1042754      중랑공영차고지(기점가상)(00001)       3       0  20240129  NaN
# 1043252  남산예장버스환승주차장(종점가상)(00025)       2     165  20240129  NaN
#
# [4358 rows x 9 columns]

# %%
# NaN 값을 제거 해주세요.
# dropna()
temp=bus_station.dropna()

# %%
# 컬럼별 NaN 값이 있는지 확인, info()
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 960811 entries, 0 to 1048574
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용일자        960811 non-null  int64
#  1   노선번호        960811 non-null  object
#  2   노선명         960811 non-null  object
#  3   버스정류장ARS번호  960811 non-null  object
#  4   역명          960811 non-null  object
#  5   승차총승객수      960811 non-null  int64
#  6   하차총승객수      960811 non-null  int64
#  7   등록일자        960811 non-null  int64
#  8   자치구         960811 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 73.3+ MB

# %%
# "버스정류장ARS번호" dtype을 정수형(int)으로 변경
temp=temp.astype({'버스정류장ARS번호':'int64'}, )
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 960811 entries, 0 to 1048574
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용일자        960811 non-null  int64
#  1   노선번호        960811 non-null  object
#  2   노선명         960811 non-null  object
#  3   버스정류장ARS번호  960811 non-null  int64
#  4   역명          960811 non-null  object
#  5   승차총승객수      960811 non-null  int64
#  6   하차총승객수      960811 non-null  int64
#  7   등록일자        960811 non-null  int64
#  8   자치구         960811 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 73.3+ MB

# %% [markdown]
# #### [실습문제5] 구별로 버스정류장의 개수 확인하기 (서울시)

# %%
# 자치구별 버스정류장 고유값들의 갯수를 출력하여 'bus_station_count' 변수로 저장
# nunique(), groupbynunique

temp.nunique()
bus_station_count=temp.groupby('자치구', as_index=False)['버스정류장ARS번호'].nunique()
bus_station_count
# Out:
#      자치구  버스정류장ARS번호
# 0    강남구         501
# 1    강동구         367
# 2    강북구         410
# 3    강서구         567
# 4    관악구         468
# 5    광진구         280
# 6    구로구         486
# 7    금천구         347
# 8    노원구         496
# 9    도봉구         368
# 10  동대문구         308
# 11   동작구         441
# 12   마포구         565
# 13  서대문구         460
# 14   서초구         601
# 15   성동구         433
# 16   성북구         599
# 17   송파구         470
# 18   양천구         323
# 19  영등포구         467
# 20   용산구         326
# 21   은평구         497
# 22   종로구         357
# 23    중구         174
# 24   중랑구         428

# %%
# 중랑구에 428개의 버스정류장이 있다는데, 실제 ARS번호를 확인해봅시다.
# 자치구별 버스정류장 고유값들을 출력하여 'bus_staiton_unique' 변수로 저장
# 중랑구 버스정류장ARS번호 전체 출력
#bus_staiton_unique=temp.groupby('자치구', as_index=False)['버스정류장ARS번호']
bus_staiton_unique=bus_station.loc[bus_station['자치구'] == '중랑구']['버스정류장ARS번호']

# %%
# 서울 지역 외 '버스정류장ARS번호' 샘플 확인 
# 중랑구의 버스정류장ARS번호 7674 인 정류장 확인해보기
bus_station[bus_station['버스정류장ARS번호']==8454]
bus_station[bus_station['버스정류장ARS번호']==7674]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선번호, 노선명, 버스정류장ARS번호, 역명, 승차총승객수, 하차총승객수, 등록일자, 자치구]
# Index: []

# %%
# 서울의 버스 정류장 데이터만 포함하고 있는 excel 파일 열기 ('1.1 bus_station_202401.xlsx')
# https://data.seoul.go.kr/dataList/OA-15067/S/1/datasetView.do (출처:서울열린데이터광장)
# 'only_seoul' 변수로 저장

only_seoul = pd.read_excel("1.1 bus_station_202401.xlsx")

# %%
# 데이터 구조 확인, info()
only_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11263 entries, 0 to 11262
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ARS_ID  11263 non-null  int64
#  1   정류소명    11263 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 176.1+ KB

# %%
# 데이터 확인

only_seoul.head()
# Out:
#    ARS_ID           정류소명
# 0    1001        종로2가사거리
# 1    1002    창경궁.서울대학교병원
# 2    1003      명륜3가.성대입구
# 3    1004       종로2가.삼일교
# 4    1005  혜화동로터리.여운형활동터

# %%
# 서울 지역 외 '버스정류장ARS번호' 샘플 확인
temp[temp['버스정류장ARS번호']==1006]
# Out:
#              사용일자 노선번호                      노선명  버스정류장ARS번호              역명  \
# 4113     20240101  N26    N26번(중랑공영차고지~강서공영차고지)        1006  서대문역사거리(00031)
# 4237     20240101  N26    N26번(강서공영차고지~중랑공영차고지)        1006  서대문역사거리(00098)
# 5619     20240101  721         721번(북가좌동~건대입구역)        1006  서대문역사거리(00072)
# 5952     20240101  270         270번(상암동차고지~망우리)        1006  서대문역사거리(00081)
# 11878    20240101  260          260번(중랑차고지~여의도)        1006  서대문역사거리(00040)
# ...           ...  ...                      ...         ...             ...
# 1023835  20240126  160            160번(도봉산~온수동)        1006  서대문역사거리(00034)
# 1024217  20240126  260          260번(중랑차고지~여의도)        1006  서대문역사거리(00040)
# 1040855  20240126  271  271번(용마문화복지센터~월드컵파크7단지)        1006  서대문역사거리(00037)
# 1041852  20240126  N75    N75번(진관공영차고지~신림2동차고지)        1006  서대문역사거리(00137)
# 1042020  20240126  N75    N75번(신림2동차고지~진관공영차고지)        1006  서대문역사거리(00050)
#
#          승차총승객수  하차총승객수      등록일자  자치구
# 4113          6       7  20240104  종로구
# 4237          1       1  20240104  종로구
# 5619        114      60  20240104  종로구
# 5952         50      78  20240104  종로구
# 11878       104      61  20240104  종로구
# ...         ...     ...       ...  ...
# 1023835     613     193  20240129  종로구
# 1024217     319     205  20240129  종로구
# 1040855     359     225  20240129  종로구
# 1041852       6       4  20240129  종로구
# 1042020       4       5  20240129  종로구
#
# [257 rows x 9 columns]

# %%
# 'ARS-ID'열 이름을 '버스정류장ARS번호'로 바꾸기
#only_seoul.rename(columns={'ARS-ID':'버스정류장ARS번호'}, inplace=True)
only_seoul['버스정류장ARS번호']=only_seoul['ARS_ID']
only_seoul.drop('ARS_ID',axis=1, inplace=True)
only_seoul.head()
# Out:
#             정류소명  버스정류장ARS번호
# 0        종로2가사거리        1001
# 1    창경궁.서울대학교병원        1002
# 2      명륜3가.성대입구        1003
# 3       종로2가.삼일교        1004
# 4  혜화동로터리.여운형활동터        1005

# %%
# 'only_seoul'과 'bus_station' 데이터 병합
ob=pd.merge(only_seoul,temp)
ob.tail(10)
# Out:
#               정류소명  버스정류장ARS번호      사용일자  노선번호                 노선명  \
# 957599  암사삼성.현대아파트       25990  20240117  강동02  강동02(가래여울~암사동서원마을)
# 957600  암사삼성.현대아파트       25990  20240118  강동02  강동02(가래여울~암사동서원마을)
# 957601  암사삼성.현대아파트       25990  20240119  강동02  강동02(가래여울~암사동서원마을)
# 957602  암사삼성.현대아파트       25990  20240120  강동02  강동02(가래여울~암사동서원마을)
# 957603  암사삼성.현대아파트       25990  20240121  강동02  강동02(가래여울~암사동서원마을)
# 957604  암사삼성.현대아파트       25990  20240122  강동02  강동02(가래여울~암사동서원마을)
# 957605  암사삼성.현대아파트       25990  20240123  강동02  강동02(가래여울~암사동서원마을)
# 957606  암사삼성.현대아파트       25990  20240124  강동02  강동02(가래여울~암사동서원마을)
# 957607  암사삼성.현대아파트       25990  20240125  강동02  강동02(가래여울~암사동서원마을)
# 957608  암사삼성.현대아파트       25990  20240126  강동02  강동02(가래여울~암사동서원마을)
#
#                        역명  승차총승객수  하차총승객수      등록일자  자치구
# 957599  암사삼성.현대아파트(00044)      92      36  20240120  강동구
# 957600  암사삼성.현대아파트(00044)      80      25  20240121  강동구
# 957601  암사삼성.현대아파트(00044)      76      36  20240122  강동구
# 957602  암사삼성.현대아파트(00044)      47      18  20240123  강동구
# 957603  암사삼성.현대아파트(00044)      31       6  20240124  강동구
# 957604  암사삼성.현대아파트(00044)      80      27  20240125  강동구
# 957605  암사삼성.현대아파트(00044)      90      29  20240126  강동구
# 957606  암사삼성.현대아파트(00044)      90      23  20240127  강동구
# 957607  암사삼성.현대아파트(00044)      88      30  20240128  강동구
# 957608  암사삼성.현대아파트(00044)      64      31  20240129  강동구

# %%
# 구 별로 버스 정류장의 개수 확인하기, 'seoul_bus_station_ARS' 변수로 저장

seoul_bus_station_ARS=ob.groupby('자치구', as_index=False)['버스정류장ARS번호'].nunique()
seoul_bus_station_ARS.head(10)
# Out:
#    자치구  버스정류장ARS번호
# 0  강남구         501
# 1  강동구         367
# 2  강북구         410
# 3  강서구         567
# 4  관악구         466
# 5  광진구         274
# 6  구로구         486
# 7  금천구         346
# 8  노원구         495
# 9  도봉구         366

# %%
# 서울시에 있는 버스정류장 개수 구하기
seoul_bus_station_ARS['버스정류장ARS번호'].sum()
# Out:
# 10652

# %% [markdown]
# #### [실습문제6] 구 별로 버스 노선의 개수 확인하기

# %%
# 자치구별 노선번호의 개수 구하기, 'seoul_bus_staion_line' 변수로 저장


seoul_bus_staion_line=seoul_bus_station_ARS=ob.groupby('자치구', as_index=False)['노선번호'].nunique()
seoul_bus_staion_line
# Out:
#      자치구  노선번호
# 0    강남구    98
# 1    강동구    22
# 2    강북구    71
# 3    강서구    51
# 4    관악구    81
# 5    광진구    43
# 6    구로구    80
# 7    금천구    56
# 8    노원구    58
# 9    도봉구    54
# 10  동대문구    74
# 11   동작구    93
# 12   마포구   100
# 13  서대문구   109
# 14   서초구    99
# 15   성동구    58
# 16   성북구    98
# 17   송파구    60
# 18   양천구    57
# 19  영등포구   100
# 20   용산구    69
# 21   은평구    74
# 22   종로구   105
# 23    중구   102
# 24   중랑구    50

# %% [markdown]
# #### [실습문제7] 각 구별로 승차 총 승객수, 하차 총 승객수 구하기

# %%
# 자치구별 "승차총승객수","하차총승객수"의 합 구하기, 'seoul_bus_station_sum' 변수로 저장
# groupby()

seoul_bus_station_sum=ob.groupby('자치구', as_index=False)[['승차총승객수','하차총승객수']].sum()
seoul_bus_station_sum
# Out:
#      자치구   승차총승객수   하차총승객수
# 0    강남구  6960336  6597087
# 1    강동구  2515582  2460905
# 2    강북구  3998077  3858057
# 3    강서구  3981173  3963283
# 4    관악구  5862490  5996915
# 5    광진구  2365355  2382437
# 6    구로구  4204229  4023135
# 7    금천구  3133461  3014364
# 8    노원구  3553485  3497450
# 9    도봉구  2771076  2695540
# 10  동대문구  4530373  4426822
# 11   동작구  4125466  3979142
# 12   마포구  4517711  4395035
# 13  서대문구  5069197  4978622
# 14   서초구  5919552  5755058
# 15   성동구  2371151  2331836
# 16   성북구  5051648  5060251
# 17   송파구  4746623  4744766
# 18   양천구  3478159  3344254
# 19  영등포구  4987187  5041026
# 20   용산구  3495720  3422432
# 21   은평구  4296944  4223666
# 22   종로구  4500874  4348356
# 23    중구  3138112  3050645
# 24   중랑구  3200879  3155827

# %% [markdown]
# #### [실습문제8] 각 구별 승차 평균 승객수, 하차 평균 승객수 구하기

# %%
# 자치구별 "승차총승객수","하차총승객수"의 평균 구하기, 'seoul_bus_station_mean' 변수로 저장
# '승차총승객수' -> '승차평균승객수', '하차총승객수' -> '하차평균승객수'로 열이름 변경
seoul_bus_station_mean=ob.groupby('자치구', as_index=False)[['승차총승객수','하차총승객수']].mean()
seoul_bus_station_mean.rename(columns={'승차총승객수': '승차평균승객수', '하차총승객수': '하차평균승객수'}, inplace=True)
seoul_bus_station_mean
# Out:
#      자치구     승차평균승객수     하차평균승객수
# 0    강남구  123.257234  116.824633
# 1    강동구   91.578944   89.588445
# 2    강북구  126.465395  122.036345
# 3    강서구   86.932767   86.542122
# 4    관악구  134.946712  138.040996
# 5    광진구  107.491706  108.267985
# 6    구로구  114.700415  109.759781
# 7    금천구  123.088384  118.410025
# 8    노원구   83.356439   82.041989
# 9    도봉구  101.649829   98.878985
# 10  동대문구  127.573018  124.657074
# 11   동작구  108.467845  104.620655
# 12   마포구   95.578543   92.983159
# 13  서대문구  104.720330  102.849216
# 14   서초구  113.621221  110.463886
# 15   성동구   90.495039   88.994581
# 16   성북구  112.288788  112.480017
# 17   송파구   99.003483   98.964751
# 18   양천구   96.452095   92.738804
# 19  영등포구  116.711217  117.971168
# 20   용산구  119.962938  117.447907
# 21   은평구   93.725603   92.127252
# 22   종로구  123.298104  119.119987
# 23    중구  113.699710  110.530616
# 24   중랑구   79.082866   77.969784

# %% [markdown]
# #### [실습문제9] 데이터 프레임 합치기

# %%
# 네 개 파일을 합쳐주세요.
df1=seoul_bus_station_ARS
df2=seoul_bus_staion_line
df3=seoul_bus_station_sum
df4=seoul_bus_station_mean
mer1=pd.merge(df1,df2)
mer2=pd.merge(df3,df4)
mer=pd.merge(mer1,mer2)
mer
# Out:
#      자치구  버스정류장ARS번호  노선번호   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수
# 0    강남구         501    98  6960336  6597087  123.257234  116.824633
# 1    강동구         367    22  2515582  2460905   91.578944   89.588445
# 2    강북구         410    71  3998077  3858057  126.465395  122.036345
# 3    강서구         567    51  3981173  3963283   86.932767   86.542122
# 4    관악구         466    81  5862490  5996915  134.946712  138.040996
# 5    광진구         274    43  2365355  2382437  107.491706  108.267985
# 6    구로구         486    80  4204229  4023135  114.700415  109.759781
# 7    금천구         346    56  3133461  3014364  123.088384  118.410025
# 8    노원구         495    58  3553485  3497450   83.356439   82.041989
# 9    도봉구         366    54  2771076  2695540  101.649829   98.878985
# 10  동대문구         307    74  4530373  4426822  127.573018  124.657074
# 11   동작구         435    93  4125466  3979142  108.467845  104.620655
# 12   마포구         558   100  4517711  4395035   95.578543   92.983159
# 13  서대문구         456   109  5069197  4978622  104.720330  102.849216
# 14   서초구         601    99  5919552  5755058  113.621221  110.463886
# 15   성동구         432    58  2371151  2331836   90.495039   88.994581
# 16   성북구         595    98  5051648  5060251  112.288788  112.480017
# 17   송파구         470    60  4746623  4744766   99.003483   98.964751
# 18   양천구         319    57  3478159  3344254   96.452095   92.738804
# 19  영등포구         465   100  4987187  5041026  116.711217  117.971168
# 20   용산구         326    69  3495720  3422432  119.962938  117.447907
# 21   은평구         497    74  4296944  4223666   93.725603   92.127252
# 22   종로구         356   105  4500874  4348356  123.298104  119.119987
# 23    중구         173   102  3138112  3050645  113.699710  110.530616
# 24   중랑구         384    50  3200879  3155827   79.082866   77.969784

# %%
# '버스정류장ARS번호' -> '정류장수', '노선번호' -> '노선수'로 열이름 변경

mer.rename(columns={'버스정류장ARS번호':'정류장수', '노선번호':'노선수'}, inplace=True)
mer
# Out:
#      자치구  정류장수  노선수   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수
# 0    강남구   501   98  6960336  6597087  123.257234  116.824633
# 1    강동구   367   22  2515582  2460905   91.578944   89.588445
# 2    강북구   410   71  3998077  3858057  126.465395  122.036345
# 3    강서구   567   51  3981173  3963283   86.932767   86.542122
# 4    관악구   466   81  5862490  5996915  134.946712  138.040996
# 5    광진구   274   43  2365355  2382437  107.491706  108.267985
# 6    구로구   486   80  4204229  4023135  114.700415  109.759781
# 7    금천구   346   56  3133461  3014364  123.088384  118.410025
# 8    노원구   495   58  3553485  3497450   83.356439   82.041989
# 9    도봉구   366   54  2771076  2695540  101.649829   98.878985
# 10  동대문구   307   74  4530373  4426822  127.573018  124.657074
# 11   동작구   435   93  4125466  3979142  108.467845  104.620655
# 12   마포구   558  100  4517711  4395035   95.578543   92.983159
# 13  서대문구   456  109  5069197  4978622  104.720330  102.849216
# 14   서초구   601   99  5919552  5755058  113.621221  110.463886
# 15   성동구   432   58  2371151  2331836   90.495039   88.994581
# 16   성북구   595   98  5051648  5060251  112.288788  112.480017
# 17   송파구   470   60  4746623  4744766   99.003483   98.964751
# 18   양천구   319   57  3478159  3344254   96.452095   92.738804
# 19  영등포구   465  100  4987187  5041026  116.711217  117.971168
# 20   용산구   326   69  3495720  3422432  119.962938  117.447907
# 21   은평구   497   74  4296944  4223666   93.725603   92.127252
# 22   종로구   356  105  4500874  4348356  123.298104  119.119987
# 23    중구   173  102  3138112  3050645  113.699710  110.530616
# 24   중랑구   384   50  3200879  3155827   79.082866   77.969784

# %%
# 데이터를 합친 결과를 확인합니다.

mer
# Out:
#      자치구  정류장수  노선수   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수
# 0    강남구   501   98  6960336  6597087  123.257234  116.824633
# 1    강동구   367   22  2515582  2460905   91.578944   89.588445
# 2    강북구   410   71  3998077  3858057  126.465395  122.036345
# 3    강서구   567   51  3981173  3963283   86.932767   86.542122
# 4    관악구   466   81  5862490  5996915  134.946712  138.040996
# 5    광진구   274   43  2365355  2382437  107.491706  108.267985
# 6    구로구   486   80  4204229  4023135  114.700415  109.759781
# 7    금천구   346   56  3133461  3014364  123.088384  118.410025
# 8    노원구   495   58  3553485  3497450   83.356439   82.041989
# 9    도봉구   366   54  2771076  2695540  101.649829   98.878985
# 10  동대문구   307   74  4530373  4426822  127.573018  124.657074
# 11   동작구   435   93  4125466  3979142  108.467845  104.620655
# 12   마포구   558  100  4517711  4395035   95.578543   92.983159
# 13  서대문구   456  109  5069197  4978622  104.720330  102.849216
# 14   서초구   601   99  5919552  5755058  113.621221  110.463886
# 15   성동구   432   58  2371151  2331836   90.495039   88.994581
# 16   성북구   595   98  5051648  5060251  112.288788  112.480017
# 17   송파구   470   60  4746623  4744766   99.003483   98.964751
# 18   양천구   319   57  3478159  3344254   96.452095   92.738804
# 19  영등포구   465  100  4987187  5041026  116.711217  117.971168
# 20   용산구   326   69  3495720  3422432  119.962938  117.447907
# 21   은평구   497   74  4296944  4223666   93.725603   92.127252
# 22   종로구   356  105  4500874  4348356  123.298104  119.119987
# 23    중구   173  102  3138112  3050645  113.699710  110.530616
# 24   중랑구   384   50  3200879  3155827   79.082866   77.969784

# %%
# 해당 데이터프레임을 csv 파일로 저장하세요.
mer.to_csv("mission1_1.csv", index = False)

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun')
sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제10] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 자치구별 정류장 수를 볼 수 있는 그래프를 출력해주세요.
mer= pd.read_csv("mission1_1.csv")

sns.barplot(x='자치구', y='정류장수', data=mer)
# Out:
# <Axes: xlabel='자치구', ylabel='정류장수'>

# %%
mer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자치구      25 non-null     object
#  1   정류장수     25 non-null     int64
#  2   노선수      25 non-null     int64
#  3   승차총승객수   25 non-null     int64
#  4   하차총승객수   25 non-null     int64
#  5   승차평균승객수  25 non-null     float64
#  6   하차평균승객수  25 non-null     float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 1.5+ KB

# %%
sns.barplot(x='자치구', y='승차평균승객수', data=mer)
# Out:
# <Axes: xlabel='자치구', ylabel='승차평균승객수'>

# %%
sns.barplot(x='자치구', y='승차총승객수', data=mer)
# Out:
# <Axes: xlabel='자치구', ylabel='승차총승객수'>

# %%
mer
# Out:
#      자치구  정류장수  노선수   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수
# 0    강남구   501   98  6960336  6597087  123.257234  116.824633
# 1    강동구   367   22  2515582  2460905   91.578944   89.588445
# 2    강북구   410   71  3998077  3858057  126.465395  122.036345
# 3    강서구   567   51  3981173  3963283   86.932767   86.542122
# 4    관악구   466   81  5862490  5996915  134.946712  138.040996
# 5    광진구   274   43  2365355  2382437  107.491706  108.267985
# 6    구로구   486   80  4204229  4023135  114.700415  109.759781
# 7    금천구   346   56  3133461  3014364  123.088384  118.410025
# 8    노원구   495   58  3553485  3497450   83.356439   82.041989
# 9    도봉구   366   54  2771076  2695540  101.649829   98.878985
# 10  동대문구   307   74  4530373  4426822  127.573018  124.657074
# 11   동작구   435   93  4125466  3979142  108.467845  104.620655
# 12   마포구   558  100  4517711  4395035   95.578543   92.983159
# 13  서대문구   456  109  5069197  4978622  104.720330  102.849216
# 14   서초구   601   99  5919552  5755058  113.621221  110.463886
# 15   성동구   432   58  2371151  2331836   90.495039   88.994581
# 16   성북구   595   98  5051648  5060251  112.288788  112.480017
# 17   송파구   470   60  4746623  4744766   99.003483   98.964751
# 18   양천구   319   57  3478159  3344254   96.452095   92.738804
# 19  영등포구   465  100  4987187  5041026  116.711217  117.971168
# 20   용산구   326   69  3495720  3422432  119.962938  117.447907
# 21   은평구   497   74  4296944  4223666   93.725603   92.127252
# 22   종로구   356  105  4500874  4348356  123.298104  119.119987
# 23    중구   173  102  3138112  3050645  113.699710  110.530616
# 24   중랑구   384   50  3200879  3155827   79.082866   77.969784

# %%
mer2=pd.read_csv("sample.csv")

# %%
data=pd.merge(mer,mer2)

# %%
data
# Out:
#      자치구  정류장수  노선수   승차총승객수   하차총승객수     승차평균승객수     하차평균승객수  평균 이동 시간(분)  \
# 0    강남구   501   98  6960336  6597087  123.257234  116.824633    90.848463
# 1    강동구   367   22  2515582  2460905   91.578944   89.588445    89.814904
# 2    강북구   410   71  3998077  3858057  126.465395  122.036345    86.136192
# 3    강서구   567   51  3981173  3963283   86.932767   86.542122    89.410804
# 4    관악구   466   81  5862490  5996915  134.946712  138.040996    84.943239
# 5    광진구   274   43  2365355  2382437  107.491706  108.267985    84.256226
# 6    구로구   486   80  4204229  4023135  114.700415  109.759781    82.615542
# 7    금천구   346   56  3133461  3014364  123.088384  118.410025    80.498803
# 8    노원구   495   58  3553485  3497450   83.356439   82.041989    86.779341
# 9    도봉구   366   54  2771076  2695540  101.649829   98.878985    84.423351
# 10  동대문구   307   74  4530373  4426822  127.573018  124.657074    83.695058
# 11   동작구   435   93  4125466  3979142  108.467845  104.620655    81.265948
# 12   마포구   558  100  4517711  4395035   95.578543   92.983159    85.531384
# 13  서대문구   456  109  5069197  4978622  104.720330  102.849216    85.333398
# 14   서초구   601   99  5919552  5755058  113.621221  110.463886    87.414696
# 15   성동구   432   58  2371151  2331836   90.495039   88.994581    81.820117
# 16   성북구   595   98  5051648  5060251  112.288788  112.480017    83.833843
# 17   송파구   470   60  4746623  4744766   99.003483   98.964751    93.374190
# 18   양천구   319   57  3478159  3344254   96.452095   92.738804    80.431447
# 19  영등포구   465  100  4987187  5041026  116.711217  117.971168    84.859361
# 20   용산구   326   69  3495720  3422432  119.962938  117.447907    82.991840
# 21   은평구   497   74  4296944  4223666   93.725603   92.127252    87.281332
# 22   종로구   356  105  4500874  4348356  123.298104  119.119987    88.403146
# 23    중구   173  102  3138112  3050645  113.699710  110.530616    85.488992
# 24   중랑구   384   50  3200879  3155827   79.082866   77.969784    83.042672
#
#       이동인구(합)    총 이동 시간       총 이동인구
# 0   48.990455  113596100  61257224.24
# 1   38.220654   67318336  28647259.60
# 2   26.098009   47088761  14267207.60
# 3   33.618231   81249296  30549525.42
# 4   28.667800   68982489  23281149.03
# 5   27.839100   64014005  21150867.55
# 6   26.746561   66237754  21444295.80
# 7   20.302710   48309183  12184123.01
# 8   33.644246   63440818  24595928.60
# 9   25.494790   43450335  13121454.52
# 10  26.258552   63583303  19948674.26
# 11  24.914132   63090087  19341862.11
# 12  32.441090   77965192  29571318.30
# 13  26.933791   64090502  20228893.27
# 14  36.342096   95421620  39670923.20
# 15  26.460990   63147048  20422036.60
# 16  28.740027   61327474  21024364.63
# 17  43.424904   99745111  46387784.83
# 18  27.926099   52859788  18353115.86
# 19  33.526089   82876792  32742818.60
# 20  22.645748   67096081  18308317.25
# 21  32.607124   57483398  21475019.31
# 22  28.184992   75660805  24122435.37
# 23  29.646272   74786540  25934825.41
# 24  27.195641   53069416  17379700.65

# %%
sns.barplot(x='노선수', y='평균 이동 시간(분)', data=data)
# Out:
# <Axes: xlabel='노선수', ylabel='평균 이동 시간(분)'>

# %%
sns.barplot(x='자치구', y='이동인구(합)', data=data)
# Out:
# <Axes: xlabel='자치구', ylabel='이동인구(합)'>

# %%
import scipy.stats as spst
spst.pearsonr(data["총 이동인구"], data['총 이동 시간'])
# Out:
# PearsonRResult(statistic=0.954666308041411, pvalue=1.3521002192233567e-13)

# %%
# 위 차트를 통해 알게된 사실을 개인별로 정리해봅시다.
# 1. 승차 평균보다 승차 총량의 편차가 극단적인 것으로 보아 운행 횟수의 차이가 있는 것 같다.
# 2. 
# 3.

# %% [markdown]
# ---
